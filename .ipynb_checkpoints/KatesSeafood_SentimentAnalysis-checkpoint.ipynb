# %% [markdown]
# # Sentiment Analysis: Kate's Seafood
#
# Author: Megan Schaeb
# Date: 8/15/2023

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel("KatesReviews.xlsx")
data
# Out:
#      Unnamed: 0 reviewer_name       reviewer_loc review_date    star_rating  \
# 0      Review 1        Ann P.   South Dennis, MA   6/12/2023  5 star rating
# 1      Review 2          K S.        Newtown, CT    8/7/2023  1 star rating
# 2      Review 3      David S.  San Francisco, CA   8/30/2022  4 star rating
# 3      Review 4       Lori G.       Maricopa, AZ    6/7/2022  5 star rating
# 4      Review 5   Brittany K.  San Francisco, CA   6/22/2021  5 star rating
# ..          ...           ...                ...         ...            ...
# 119  Review 120        Jan A.    South Salem, NY   9/14/2008  4 star rating
# 120  Review 121         K. L.       Trumbull, CT   8/19/2013  3 star rating
# 121  Review 122     Brooke K.         Woburn, MA   5/14/2012  5 star rating
# 122  Review 123        Tom H.      Braintree, MA    9/1/2013  5 star rating
# 123  Review 124      Norma T.        Eastham, MA    8/2/2013  1 star rating
#
#                                            review_text
# 0    A group of us enjoyed lunch today. Service was...
# 1    Are you kidding me?  Here we go with no real m...
# 2    Was back at Kate's for the 2nd time this summe...
# 3    Kate's is open again this summer and they've u...
# 4    The clam strips were fantastic, Cape Cod Reube...
# ..                                                 ...
# 119  Window service. I have only every had the ice ...
# 120  This place is OK but not the best ice cream. O...
# 121  When my husband, who's been coming here for ye...
# 122  Hidden gem.  Drive past this place for 10 year...
# 123  Ordered the whole belly clam roll and it was t...
#
# [124 rows x 6 columns]

# %%
data.shape
# Out:
# (124, 6)

# %%
data2 = data.copy()
data2
# Out:
#      Unnamed: 0 reviewer_name       reviewer_loc review_date    star_rating  \
# 0      Review 1        Ann P.   South Dennis, MA   6/12/2023  5 star rating
# 1      Review 2          K S.        Newtown, CT    8/7/2023  1 star rating
# 2      Review 3      David S.  San Francisco, CA   8/30/2022  4 star rating
# 3      Review 4       Lori G.       Maricopa, AZ    6/7/2022  5 star rating
# 4      Review 5   Brittany K.  San Francisco, CA   6/22/2021  5 star rating
# ..          ...           ...                ...         ...            ...
# 119  Review 120        Jan A.    South Salem, NY   9/14/2008  4 star rating
# 120  Review 121         K. L.       Trumbull, CT   8/19/2013  3 star rating
# 121  Review 122     Brooke K.         Woburn, MA   5/14/2012  5 star rating
# 122  Review 123        Tom H.      Braintree, MA    9/1/2013  5 star rating
# 123  Review 124      Norma T.        Eastham, MA    8/2/2013  1 star rating
#
#                                            review_text
# 0    A group of us enjoyed lunch today. Service was...
# 1    Are you kidding me?  Here we go with no real m...
# 2    Was back at Kate's for the 2nd time this summe...
# 3    Kate's is open again this summer and they've u...
# 4    The clam strips were fantastic, Cape Cod Reube...
# ..                                                 ...
# 119  Window service. I have only every had the ice ...
# 120  This place is OK but not the best ice cream. O...
# 121  When my husband, who's been coming here for ye...
# 122  Hidden gem.  Drive past this place for 10 year...
# 123  Ordered the whole belly clam roll and it was t...
#
# [124 rows x 6 columns]

# %%
def get_city(loc):
    list_loc = loc.split(", ")
    city = pd.Series(list_loc[0])
    return city

def get_state(loc):
    list_loc = loc.split(", ")
    state = pd.Series(list_loc[1])
    return state

# %%
data2["reviewer_city"] = data2["reviewer_loc"].apply(lambda loc: get_city(loc))
data2["reviewer_state"] = data2["reviewer_loc"].apply(lambda loc: get_state(loc))
data2
# Out:
#      Unnamed: 0 reviewer_name       reviewer_loc review_date    star_rating  \
# 0      Review 1        Ann P.   South Dennis, MA   6/12/2023  5 star rating
# 1      Review 2          K S.        Newtown, CT    8/7/2023  1 star rating
# 2      Review 3      David S.  San Francisco, CA   8/30/2022  4 star rating
# 3      Review 4       Lori G.       Maricopa, AZ    6/7/2022  5 star rating
# 4      Review 5   Brittany K.  San Francisco, CA   6/22/2021  5 star rating
# ..          ...           ...                ...         ...            ...
# 119  Review 120        Jan A.    South Salem, NY   9/14/2008  4 star rating
# 120  Review 121         K. L.       Trumbull, CT   8/19/2013  3 star rating
# 121  Review 122     Brooke K.         Woburn, MA   5/14/2012  5 star rating
# 122  Review 123        Tom H.      Braintree, MA    9/1/2013  5 star rating
# 123  Review 124      Norma T.        Eastham, MA    8/2/2013  1 star rating
#
#                                            review_text           city state
# 0    A group of us enjoyed lunch today. Service was...   South Dennis    MA
# 1    Are you kidding me?  Here we go with no real m...        Newtown    CT
# 2    Was back at Kate's for the 2nd time this summe...  San Francisco    CA
# 3    Kate's is open again this summer and they've u...       Maricopa    AZ
# 4    The clam strips were fantastic, Cape Cod Reube...  San Francisco    CA
# ..                                                 ...            ...   ...
# 119  Window service. I have only every had the ice ...    South Salem    NY
# 120  This place is OK but not the best ice cream. O...       Trumbull    CT
# 121  When my husband, who's been coming here for ye...         Woburn    MA
# 122  Hidden gem.  Drive past this place for 10 year...      Braintree    MA
# 123  Ordered the whole belly clam roll and it was t...        Eastham    MA
#
# [124 rows x 8 columns]

# %%
def convert_score(score):
    num_score = int(score.split(" ")[0])
    return num_score

# %%
data2["rating"] = data2["star_rating"].apply(lambda score: convert_score(score))
data2
# Out:
#      Unnamed: 0 reviewer_name       reviewer_loc review_date    star_rating  \
# 0      Review 1        Ann P.   South Dennis, MA   6/12/2023  5 star rating
# 1      Review 2          K S.        Newtown, CT    8/7/2023  1 star rating
# 2      Review 3      David S.  San Francisco, CA   8/30/2022  4 star rating
# 3      Review 4       Lori G.       Maricopa, AZ    6/7/2022  5 star rating
# 4      Review 5   Brittany K.  San Francisco, CA   6/22/2021  5 star rating
# ..          ...           ...                ...         ...            ...
# 119  Review 120        Jan A.    South Salem, NY   9/14/2008  4 star rating
# 120  Review 121         K. L.       Trumbull, CT   8/19/2013  3 star rating
# 121  Review 122     Brooke K.         Woburn, MA   5/14/2012  5 star rating
# 122  Review 123        Tom H.      Braintree, MA    9/1/2013  5 star rating
# 123  Review 124      Norma T.        Eastham, MA    8/2/2013  1 star rating
#
#                                            review_text           city state  \
# 0    A group of us enjoyed lunch today. Service was...   South Dennis    MA
# 1    Are you kidding me?  Here we go with no real m...        Newtown    CT
# 2    Was back at Kate's for the 2nd time this summe...  San Francisco    CA
# 3    Kate's is open again this summer and they've u...       Maricopa    AZ
# 4    The clam strips were fantastic, Cape Cod Reube...  San Francisco    CA
# ..                                                 ...            ...   ...
# 119  Window service. I have only every had the ice ...    South Salem    NY
# 120  This place is OK but not the best ice cream. O...       Trumbull    CT
# 121  When my husband, who's been coming here for ye...         Woburn    MA
# 122  Hidden gem.  Drive past this place for 10 year...      Braintree    MA
# 123  Ordered the whole belly clam roll and it was t...        Eastham    MA
#
#      rating
# 0         5
# 1         1
# 2         4
# 3         5
# 4         5
# ..      ...
# 119       4
# 120       3
# 121       5
# 122       5
# 123       1
#
# [124 rows x 9 columns]

# %%
# drop review number column
data2.drop('Unnamed: 0', axis=1, inplace=True)
data2
# Out:
#     reviewer_name       reviewer_loc review_date    star_rating  \
# 0          Ann P.   South Dennis, MA   6/12/2023  5 star rating
# 1            K S.        Newtown, CT    8/7/2023  1 star rating
# 2        David S.  San Francisco, CA   8/30/2022  4 star rating
# 3         Lori G.       Maricopa, AZ    6/7/2022  5 star rating
# 4     Brittany K.  San Francisco, CA   6/22/2021  5 star rating
# ..            ...                ...         ...            ...
# 119        Jan A.    South Salem, NY   9/14/2008  4 star rating
# 120         K. L.       Trumbull, CT   8/19/2013  3 star rating
# 121     Brooke K.         Woburn, MA   5/14/2012  5 star rating
# 122        Tom H.      Braintree, MA    9/1/2013  5 star rating
# 123      Norma T.        Eastham, MA    8/2/2013  1 star rating
#
#                                            review_text           city state  \
# 0    A group of us enjoyed lunch today. Service was...   South Dennis    MA
# 1    Are you kidding me?  Here we go with no real m...        Newtown    CT
# 2    Was back at Kate's for the 2nd time this summe...  San Francisco    CA
# 3    Kate's is open again this summer and they've u...       Maricopa    AZ
# 4    The clam strips were fantastic, Cape Cod Reube...  San Francisco    CA
# ..                                                 ...            ...   ...
# 119  Window service. I have only every had the ice ...    South Salem    NY
# 120  This place is OK but not the best ice cream. O...       Trumbull    CT
# 121  When my husband, who's been coming here for ye...         Woburn    MA
# 122  Hidden gem.  Drive past this place for 10 year...      Braintree    MA
# 123  Ordered the whole belly clam roll and it was t...        Eastham    MA
#
#      rating
# 0         5
# 1         1
# 2         4
# 3         5
# 4         5
# ..      ...
# 119       4
# 120       3
# 121       5
# 122       5
# 123       1
#
# [124 rows x 8 columns]
